# %%
import os
import sys 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 현재 작업 중인 Notebook의 경로 가져오기
notebook_dir = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(notebook_dir, "../../../utils")))
sys.path.append(os.path.abspath(os.path.join(notebook_dir, "../../../class")))

from data import preprocess_data
from Train import Train

# 데이터 섞는 함수
def shuffle_data(inputs, targets):
    indices = np.random.permutation(inputs.shape[0])  # 데이터 인덱스 섞기
    return inputs[indices], targets[indices]

# 실험 설정
csv_path = "../../../Data/font_data.csv"

train_instance = Train(
    epoch=20,
    batch=64,
    activation="relu",
    output_activation="softmax",
    weight_init="He",
    optimizer="adam",
    dropout=0.5,
    learning_rate=0.01,
)

# 데이터 로드
inputs, targets_one_hot, targets = train_instance.load_data(csv_path)
print("load complete")
# 데이터 섞기
inputs, targets_one_hot = shuffle_data(inputs, targets_one_hot)

# K-Fold Cross Validation 준비
folds = train_instance.k_fold_split(inputs, targets_one_hot)


# 학습 실행
for i, (X_train, y_train, X_val, y_val) in enumerate(folds):
    # print("X_train shape:", X_train.shape)  # 각 fold의 데이터 크기 확인
    # print("X_val shape:", X_val.shape)
    print(f"Fold {i + 1}/{len(folds)}")
    train_instance.train(X_train, y_train, X_val, y_val)

# 결과 저장 및 시각화
train_instance.save_results(results_path="dropout05.csv",weights_path="dropout05_weights.csv")
train_instance.plot_history()
# Out:
# load complete
# X_train shape: (13552, 4096)
# X_val shape: (3388, 4096)
# Fold 1/5
# BATCH
# BATCH
# BATCH
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 49
#      47     print("X_val shape:", X_val.shape)
#      48     print(f"Fold {i + 1}/{len(folds)}")
# ---> 49     train_instance.train(X_train, y_train, X_val, y_val)
#      51 # 결과 저장 및 시각화
#      52 train_instance.save_results(results_path="dropout05.csv",weights_path="dropout05_weights.csv")
#
# File ~/Documents/GitHub/neural_network/src/class/Train.py:69, in Train.train(self, X_train, y_train, X_val, y_val)
#      67         self.model.set_target_layer(np.argmax(y))
#      68         self.model.forward_propagation()
# ---> 69         self.model.backward_propagation()
#      71 train_loss, train_accuracy = self.evaluate_cross_entropy(X_train, y_train)
#      72 val_loss, val_accuracy = self.evaluate_cross_entropy(X_val, y_val)
#
# File ~/Documents/GitHub/neural_network/src/class/NeuralNetwork.py:88, in NeuralNetwork.backward_propagation(self)
#      86 for i in range(1,len(self.layers)):
#      87     prev_layer_vals = [node.val for node in self.layers[i-1].nodes]
# ---> 88     self.layers[i].update_weight(prev_layer_vals,i)
#
# File ~/Documents/GitHub/neural_network/src/class/Layer.py:116, in Layer.update_weight(self, prev_layer_val, what_layer)
#     112 for i,node in enumerate(self.nodes):
#     113     for j,weight in enumerate(node.weight):
#     114         # print("------------------------------------")
#     115         # print(weight)
# --> 116         weight-=self.learning_rate*node.gradient*prev_layer_val[j]
#     117         self.nodes[i].weight[j]=weight
#
# KeyboardInterrupt:

# %%
import os
import sys 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 현재 작업 중인 Notebook의 경로 가져오기
notebook_dir = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(notebook_dir, "../../../utils")))
sys.path.append(os.path.abspath(os.path.join(notebook_dir, "../../../class")))

from data import preprocess_data
from Train import Train

# 데이터 섞는 함수
def shuffle_data(inputs, targets):
    indices = np.random.permutation(inputs.shape[0])  # 데이터 인덱스 섞기
    return inputs[indices], targets[indices]

# 실험 설정
csv_path = "../../../Data/font_data.csv"

train_instance = Train(
    epoch=20,
    batch=64,
    activation="relu",
    output_activation="softmax",
    weight_init="He",
    optimizer="adam",
    dropout=0.1,
    learning_rate=0.01,
)

# 데이터 로드
inputs, targets_one_hot, targets = train_instance.load_data(csv_path)

# 데이터 섞기
inputs, targets_one_hot = shuffle_data(inputs, targets_one_hot)

# K-Fold Cross Validation 준비
folds = train_instance.k_fold_split(inputs, targets_one_hot)

# 학습 실행
for i, (X_train, y_train, X_val, y_val) in enumerate(folds):
    print(f"Fold {i + 1}/{len(folds)}")
    train_instance.train(X_train, y_train, X_val, y_val)

# 결과 저장 및 시각화
train_instance.save_results(results_path="dropout01.csv",weights_path="dropout01_weights.csv")
train_instance.plot_history()

# %%
import os
import sys 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 현재 작업 중인 Notebook의 경로 가져오기
notebook_dir = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(notebook_dir, "../../../utils")))
sys.path.append(os.path.abspath(os.path.join(notebook_dir, "../../../class")))

from data import preprocess_data
from Train import Train

# 데이터 섞는 함수
def shuffle_data(inputs, targets):
    indices = np.random.permutation(inputs.shape[0])  # 데이터 인덱스 섞기
    return inputs[indices], targets[indices]

# 실험 설정
csv_path = "../../../Data/font_data.csv"

train_instance = Train(
    epoch=20,
    batch=64,
    activation="relu",
    output_activation="softmax",
    weight_init="xavier",
    optimizer="adam",
    dropout=0.1,
    learning_rate=0.01,
)

# 데이터 로드
inputs, targets_one_hot, targets = train_instance.load_data(csv_path)

# 데이터 섞기
inputs, targets_one_hot = shuffle_data(inputs, targets_one_hot)

# K-Fold Cross Validation 준비
folds = train_instance.k_fold_split(inputs, targets_one_hot)

# 학습 실행
for i, (X_train, y_train, X_val, y_val) in enumerate(folds):
    print(f"Fold {i + 1}/{len(folds)}")
    train_instance.train(X_train, y_train, X_val, y_val)

# 결과 저장 및 시각화
train_instance.save_results(results_path="dropout01_xavier.csv",weights_path="dropout01_xavier_weights.csv")
train_instance.plot_history()
