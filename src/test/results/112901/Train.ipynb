# %%
import os
import sys 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 현재 작업 중인 Notebook의 경로 가져오기
notebook_dir = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(notebook_dir, "../../../utils")))

from data import preprocess_data

csv_path = "../../../Data/font_data.csv"
inputs, targets_one_hot, targets = preprocess_data(csv_path)
print(f"Inputs Shape: {inputs.shape}")
print(f"Targets Shape: {targets_one_hot.shape}")
print(inputs[3])

image_array = np.asfarray(inputs[3]).reshape((28, 28))
plt.imshow(image_array, cmap='gray', interpolation='None')
plt.show()

print(targets[3])
# Out:
# Inputs Shape: (1540, 784)
# Targets Shape: (1540, 154)
# [0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.98823528 0.98823528
#  0.98823528 0.98823528 0.98823528 0.99215685 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99607842 0.98823528 0.99607842
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.97254901
#  0.81960783 0.81960783 0.81960783 0.8235294  0.80784313 0.81568627
#  0.98431372 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99215685 0.99999999 0.83921568 0.         0.
#  0.         0.         0.         0.02352941 0.98431372 0.83921568
#  0.25098039 0.62745097 0.99215685 0.98039215 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99607842
#  0.99999999 0.91764705 0.44313725 0.44313725 0.43529411 0.44313725
#  0.10980392 0.03137255 0.99999999 0.77254901 0.         0.49803921
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.25490196 0.
#  0.99999999 0.78431372 0.01176471 0.45490196 0.87058823 0.89411764
#  0.99999999 0.99607842 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99607842 0.98039215 0.98039215
#  0.96862744 0.98039215 0.23137255 0.         0.99999999 0.76470587
#  0.         0.         0.         0.25490196 0.99999999 0.98431372
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.98823528 0.99999999
#  0.23529412 0.         0.99999999 0.77254901 0.         0.20392157
#  0.37254902 0.56078431 0.99999999 0.98823528 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.98823528 0.99999999 0.24313725 0.01176471
#  0.99999999 0.78431372 0.         0.54509803 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.98823528 0.99999999 0.19607843 0.         0.99999999 0.78431372
#  0.         0.50196078 0.98431372 0.96862744 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99607842 0.99999999
#  0.80784313 0.74117646 0.99999999 0.77254901 0.         0.50980392
#  0.99999999 0.98039215 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.76862744 0.         0.50980392 0.99999999 0.98039215
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99215685 0.97647058 0.99999999 0.76862744
#  0.00392157 0.50980392 0.99999999 0.98039215 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.98039215 0.98039215 0.7490196  0.         0.4862745
#  0.98039215 0.96862744 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.85098038 0.10196078 0.59999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99215685 0.99999999 0.78039215 0.49803921 0.49411764
#  0.4117647  0.47058823 0.50980392 0.65882352 0.99999999 0.99215685
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.98431372
#  0.99999999 0.52941176 0.         0.         0.         0.
#  0.         0.21960784 0.99999999 0.98039215 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.98431372 0.99999999 0.58431372
#  0.01960784 0.56078431 0.77647058 0.77254901 0.78431372 0.85098038
#  0.99999999 0.99607842 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.98431372 0.99999999 0.56862745 0.         0.13333333
#  0.16470588 0.17647059 0.16470588 0.42352941 0.99999999 0.98823528
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.98431372
#  0.99999999 0.56470588 0.         0.08235294 0.09019608 0.10588235
#  0.09019608 0.37254902 0.99999999 0.98431372 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.98431372 0.99999999 0.58431372
#  0.00392157 0.74509803 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.98431372 0.99999999 0.55686274 0.         0.12941176
#  0.17254902 0.18039216 0.17254902 0.42745098 0.99999999 0.98823528
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.98431372
#  0.99999999 0.60784313 0.09803921 0.08235294 0.05098039 0.06666667
#  0.05098039 0.34509804 0.99999999 0.98431372 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99215685
#  0.98039215 0.98431372 0.98823528 0.98823528 0.98823528 0.99215685
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99607842 0.99607842 0.99607842 0.99607842
#  0.99607842 0.99999999 0.99999999 0.99999999 0.99999999 0.99999999
#  0.99999999 0.99999999 0.99999999 0.99999999]
# 3

# %%
import os
import sys 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 현재 작업 중인 Notebook의 경로 가져오기
notebook_dir = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(notebook_dir, "../../../utils")))
sys.path.append(os.path.abspath(os.path.join(notebook_dir, "../../../class")))

from data import preprocess_data

from Train import Train

# 실험 설정
csv_path = "../../../Data/font_data 2.csv"

train_instance = Train(
    epoch=20,
    batch=10,
    activation="relu",
    output_activation="softmax",
    weight_init="He",
    learning_rate=0.1,
    optimizer="none",
    dropout=0
)

# 데이터 로드
inputs, targets_one_hot, targets = train_instance.load_data(csv_path)

# K-Fold Cross Validation 준비
folds = train_instance.k_fold_split(inputs, targets_one_hot)
# 학습 실행
for i, (X_train, y_train, X_val, y_val) in enumerate(folds):
    print(f"Fold {i + 1}/{len(folds)}")
    train_instance.train(X_train, y_train, X_val, y_val)
# Out:
# Fold 1/5
# Epoch 1/20, Loss: 1.0, Accuracy: 0.006493506493506494, Val Loss: 1.0, Val Accuracy: 0.006493506493506494
# Epoch 2/20, Loss: 1.0, Accuracy: 0.006493506493506494, Val Loss: 1.0, Val Accuracy: 0.006493506493506494
# Epoch 3/20, Loss: 1.0, Accuracy: 0.006493506493506494, Val Loss: 1.0, Val Accuracy: 0.006493506493506494
# Epoch 4/20, Loss: 1.0, Accuracy: 0.006493506493506494, Val Loss: 1.0, Val Accuracy: 0.006493506493506494
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 38
#      36 for i, (X_train, y_train, X_val, y_val) in enumerate(folds):
#      37     print(f"Fold {i + 1}/{len(folds)}")
# ---> 38     train_instance.train(X_train, y_train, X_val, y_val)
#
# File ~/Documents/GitHub/neural_network/src/class/Train.py:69, in Train.train(self, X_train, y_train, X_val, y_val)
#      67         self.model.set_target_layer(np.argmax(y))
#      68         self.model.forward_propagation()
# ---> 69         self.model.backward_propagation()
#      71 train_loss, train_accuracy = self.evaluate(X_train, y_train)
#      72 val_loss, val_accuracy = self.evaluate(X_val, y_val)
#
# File ~/Documents/GitHub/neural_network/src/class/NeuralNetwork.py:88, in NeuralNetwork.backward_propagation(self)
#      86 for i in range(1,len(self.layers)):
#      87     prev_layer_vals = [node.val for node in self.layers[i-1].nodes]
# ---> 88     self.layers[i].update_weight(prev_layer_vals,i)
#
# File ~/Documents/GitHub/neural_network/src/class/Layer.py:113, in Layer.update_weight(self, prev_layer_val, what_layer)
#     111 def update_weight(self,prev_layer_val,what_layer):
#     112     for i,node in enumerate(self.nodes):
# --> 113         for j,weight in enumerate(node.weight):
#     114             # print("------------------------------------")
#     115             # print(weight)
#     116             weight-=self.learning_rate*node.gradient*prev_layer_val[j]
#     117             self.nodes[i].weight[j]=weight
#
# KeyboardInterrupt:

# %%
# 결과 저장 및 시각화
train_instance.save_results()
train_instance.plot_history()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 # 결과 저장 및 시각화
# ----> 2 train_instance.save_results()
#       3 train_instance.plot_history()
#
# File ~/Documents/GitHub/neural_network/src/class/Train.py:111, in Train.save_results(self, results_path, weights_path)
#     109 history_df = pd.DataFrame(self.history)
#     110 history_df.to_csv(results_path, index=False)
# --> 111 self.model.store_weight(weights_path)
#
# File ~/Documents/GitHub/neural_network/src/class/NeuralNetwork.py:103, in NeuralNetwork.store_weight(self, file_name)
#      97         weights_data.append({
#      98             "Layer": i,
#      99             "Node": layer.nodes.index(node),
#     100             "Weights": node.weight
#     101         })
#     102 df = pd.DataFrame(weights_data)
# --> 103 df.to_csv(file_name, index=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/formats/format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/formats/csvs.py:259, in CSVFormatter.save(self)
#     240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#    (...)
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
# --> 259     self._save()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/formats/csvs.py:264, in CSVFormatter._save(self)
#     262 if self._need_to_save_header:
#     263     self._save_header()
# --> 264 self._save_body()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/formats/csvs.py:302, in CSVFormatter._save_body(self)
#     300 if start_i >= end_i:
#     301     break
# --> 302 self._save_chunk(start_i, end_i)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/formats/csvs.py:313, in CSVFormatter._save_chunk(self, start_i, end_i)
#     310 data = [res.iget_values(i) for i in range(len(res.items))]
#     312 ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 313 libwriters.write_csv_rows(
#     314     data,
#     315     ix,
#     316     self.nlevels,
#     317     self.cols,
#     318     self.writer,
#     319 )
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/_libs/writers.pyx:72, in pandas._libs.writers.write_csv_rows()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/arrayprint.py:1588, in _array_str_implementation(a, max_line_width, precision, suppress_small, array2string)
#    1582 if a.shape == ():
#    1583     # obtain a scalar and call str on it, avoiding problems for subclasses
#    1584     # for which indexing with () returns a 0d instead of a scalar by using
#    1585     # ndarray's getindex. Also guard against recursive 0d object arrays.
#    1586     return _guarded_repr_or_str(np.ndarray.__getitem__(a, ()))
# -> 1588 return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/arrayprint.py:736, in array2string(a, max_line_width, precision, suppress_small, separator, prefix, style, formatter, threshold, edgeitems, sign, floatmode, suffix, legacy)
#     733 if a.size == 0:
#     734     return "[]"
# --> 736 return _array2string(a, options, separator, prefix)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/arrayprint.py:513, in _recursive_guard.<locals>.decorating_function.<locals>.wrapper(self, *args, **kwargs)
#     511 repr_running.add(key)
#     512 try:
# --> 513     return f(self, *args, **kwargs)
#     514 finally:
#     515     repr_running.discard(key)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/arrayprint.py:546, in _array2string(a, options, separator, prefix)
#     543 # skip over array(
#     544 next_line_prefix += " "*len(prefix)
# --> 546 lst = _formatArray(a, format_function, options['linewidth'],
#     547                    next_line_prefix, separator, options['edgeitems'],
#     548                    summary_insert, options['legacy'])
#     549 return lst
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/arrayprint.py:889, in _formatArray(a, format_function, line_width, next_line_prefix, separator, edge_items, summary_insert, legacy)
#     885     return s
#     887 try:
#     888     # invoke the recursive part with an initial index and prefix
# --> 889     return recurser(index=(),
#     890                     hanging_indent=next_line_prefix,
#     891                     curr_width=line_width)
#     892 finally:
#     893     # recursive closures have a cyclic reference to themselves, which
#     894     # requires gc to collect (gh-10620). To avoid this problem, for
#     895     # performance and PyPy friendliness, we break the cycle:
#     896     recurser = None
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/arrayprint.py:846, in _formatArray.<locals>.recurser(index, hanging_indent, curr_width)
#     844 for i in range(trailing_items, 1, -1):
#     845     word = recurser(index + (-i,), next_hanging_indent, next_width)
# --> 846     s, line = _extendLine_pretty(
#     847         s, line, word, elem_width, hanging_indent, legacy)
#     848     line += separator
#     850 if legacy <= 113:
#     851     # width of the separator is not considered on 1.13
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/arrayprint.py:759, in _extendLine_pretty(s, line, word, line_width, next_line_prefix, legacy)
#     757 words = word.splitlines()
#     758 if len(words) == 1 or legacy <= 113:
# --> 759     return _extendLine(s, line, word, line_width, next_line_prefix, legacy)
#     761 max_word_length = max(len(word) for word in words)
#     762 if (len(line) + max_word_length > line_width and
#     763         len(line) > len(next_line_prefix)):
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/arrayprint.py:740, in _extendLine(s, line, word, line_width, next_line_prefix, legacy)
#     739 def _extendLine(s, line, word, line_width, next_line_prefix, legacy):
# --> 740     needs_wrap = len(line) + len(word) > line_width
#     741     if legacy > 113:
#     742         # don't wrap lines if it won't help
#     743         if len(line) <= len(next_line_prefix):
#
# KeyboardInterrupt:
